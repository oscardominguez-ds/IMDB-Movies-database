# %%
import pandas as pd
#Concat resource - https://pandas.pydata.org/docs/user_guide/merging.html

df_2000 = pd.read_csv("Data/final_tmdb_data_2000.csv.gz", low_memory = False)
df_2001 = pd.read_csv("Data/final_tmdb_data_2001.csv.gz", low_memory = False)

#df_2000.info()

frames = [df_2000, df_2001]

result = pd.concat(frames)
result.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
# ...

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2567 entries, 0 to 1329
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2567 non-null   object
#  1   adult                  2565 non-null   float64
#  2   backdrop_path          1395 non-null   object
#  3   belongs_to_collection  206 non-null    object
#  4   budget                 2565 non-null   float64
#  5   genres                 2565 non-null   object
#  6   homepage               173 non-null    object
#  7   id                     2565 non-null   float64
#  8   original_language      2565 non-null   object
#  9   original_title         2565 non-null   object
#  10  overview               2515 non-null   object
#  11  popularity             2565 non-null   float64
#  12  poster_path            2307 non-null   object
#  13  production_companies   2565 non-null   object
# ...

# %% [markdown]
# # How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# - Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
#Creating filter for revenue then filering dataframe to get values
filter = (result['budget'] > 0) | (result['revenue'] > 0)
filter.value_counts()
#result_filtered = result[filter]
#print(f'There are a total of {result_filtered.shape[0]} movies that had valid financial for budget')
# Out:
# False    1931
# True      636
# dtype: int64

# %%
# #Creating filter for revenue then filering dataframe to get values
# filter = result['revenue'] > 0 
# filter.value_counts()
# #result_filtered = result[filter]
# #print(f'There are a total of {result_filtered.shape[0]} movies that had valid financial for budget')
# Out:
# False    2122
# True      445
# Name: revenue, dtype: int64

# %% [markdown]
# # How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
result['certification'].value_counts()
# Out:
# R          465
# PG-13      182
# NR          73
# PG          63
# G           25
# NC-17        6
# Unrated      1
# Name: certification, dtype: int64

# %%
# Filter to dataframe then value_counts()
# Resource - 
# https://stackoverflow.com/questions/63529322/how-to-create-new-dataframe-by-filtering-a-column-of-another-dataframe

df_new = result[(result['budget'] > 0) | (result['revenue'] > 0)]

df_new['certification'].value_counts()
# Out:
# R        231
# PG-13    131
# PG        35
# NR        17
# G         15
# Name: certification, dtype: int64

# %% [markdown]
# # 3. What is the average revenue per certification category?

# %%
#Using group 
df_new.groupby('certification')['revenue'].mean().astype(int)

# revenue_per_certification = result.groupby('certification')['revenue'].mean()
# revenue_per_certification.astype(int)
# Out:
# certification
# G        117364760
# NR         9588674
# PG       110640517
# PG-13     99287858
# R         32485246
# Name: revenue, dtype: int64

# %% [markdown]
# # What is the average budget per certification category?

# %%
df_new.groupby('certification')['budget'].mean().astype(int)
# Out:
# certification
# G        38133333
# NR        6302358
# PG       44828492
# PG-13    42993571
# R        19494824
# Name: budget, dtype: int64

# %%
# Save dataframe to file.
result.to_csv("Data/title_imdb.csv.gz",compression='gzip',index=False)
result
# Out:
#         imdb_id  adult                     backdrop_path  \
# 0             0    NaN                               NaN
# 1     tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2     tt0113092    0.0                               NaN
# 3     tt0116391    0.0                               NaN
# 4     tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# ...         ...    ...                               ...
# 1325  tt7797670    0.0                               NaN
# 1326  tt7797790    0.0                               NaN
# 1327  tt8665056    0.0                               NaN
# 1328  tt8795764    0.0                               NaN
# 1329  tt9071078    0.0                               NaN
#
#      belongs_to_collection      budget  \
# 0                      NaN         NaN
# 1                      NaN  10000000.0
# 2                      NaN         0.0
# 3                      NaN         0.0
# 4                      NaN    150000.0
# ...
