# %% [markdown]
# # Oscar Dominguez

# %%
# imports
import pandas as pd

# Numpy
import numpy as np

# %% [markdown]
# # Akas table:
# - keep only US movies.
# - Replace "\N" with np.nan

# %%
# # example making new folder with os
# import os
# os.makedirs('Data/',exist_ok=True) 
# # Confirm folder created
# os.listdir("Data/")

# %%
# #Loading Akas data
# akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
# #akas_url = "Data/title.akas.tsv.gz"
# akas = pd.read_csv(akas_url, sep='\t', low_memory=False)
# akas.info()

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35723981 entries, 0 to 35723980
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ GB

# %% [markdown]
# ## keep only US movies.

# %%
#Creating new dataset with the rows that have US in region
akas_us = akas[akas['region']== 'US']
akas_us
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35723507  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35723577  tt9916620         1                          The Copeland Case
# 35723666  tt9916702         1              Loving London: The Playground
# 35723709  tt9916756         1                   Pretty Pretty Black Girl
# 35723725  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 35723507     US       \N  imdbDisplay                     \N               0
# 35723577     US       \N  imdbDisplay                     \N               0
# 35723666     US       \N           \N                     \N               0
# 35723709     US       \N  imdbDisplay                     \N               0
# 35723725     US       \N  imdbDisplay                     \N               0
#
# [1432658 rows x 8 columns]

# %% [markdown]
# ## Replace "\N" with np.nan

# %%
#I will use this code below to check that \N was replaced by NaN
akas_us.isnull().sum(axis = 0)
# Out:
# titleId            0
# ordering           0
# title              0
# region             0
# language           0
# types              0
# attributes         0
# isOriginalTitle    0
# dtype: int64

# %%
#Replacing \N with NaN and displaying dataframe to look for NaN values
akas_us.replace({'\\N':np.nan}, inplace=True)
akas_us
# Out:
# /var/folders/5f/y13jb9491kgdgn16m3t57fq80000gn/T/ipykernel_23138/3788245724.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   akas_us.replace({'\\N':np.nan}, inplace=True)
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 35723507  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 35723577  tt9916620         1                          The Copeland Case
# 35723666  tt9916702         1              Loving London: The Playground
# 35723709  tt9916756         1                   Pretty Pretty Black Girl
# 35723725  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 35723507     US      NaN  imdbDisplay                    NaN               0
# 35723577     US      NaN  imdbDisplay                    NaN               0
# 35723666     US      NaN          NaN                    NaN               0
# 35723709     US      NaN  imdbDisplay                    NaN               0
# 35723725     US      NaN  imdbDisplay                    NaN               0
#
# [1432658 rows x 8 columns]

# %%
# #Save current dataframe to file.
akas.to_csv("Data/title_akas_us_cleaned.csv.gz",compression='gzip',index=False)

# %%
#Counting NaN value to ensure they replaced \N
akas_us.isnull().sum(axis = 0)
# Out:
# titleId                  0
# ordering                 0
# title                    0
# region                   0
# language           1428764
# types               454500
# attributes         1386202
# isOriginalTitle       1345
# dtype: int64

# %% [markdown]
# # Basics table:
# - Replace "\N" with np.nan
# - Eliminate movies that are null for runtimeMinutes
# - Eliminate movies that are null for genre
# - keep only titleType==Movie
# - keep startYear 2000-2022
# - Eliminate movies that include "Documentary" in genre (see tip below)
# - Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

# %%
# #Loading basics data
# basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
# basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
# basics.info()

# %%
#Save current dataframe to file.
#basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9806297 entries, 0 to 9806296
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 673.3+ MB

# %% [markdown]
# ## Replace "\N" with np.nan

# %%
#Replacing all \N values with NaN
basics.replace({'\\N':np.nan}, inplace=True)
basics
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9806292  tt9916848  tvEpisode              Episode #3.17
# 9806293  tt9916850  tvEpisode              Episode #3.19
# 9806294  tt9916852  tvEpisode              Episode #3.20
# 9806295  tt9916856      short                   The Wind
# 9806296  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894     NaN              1
# 1           Le clown et ses chiens       0      1892     NaN              5
# 2                   Pauvre Pierrot       0      1892     NaN              4
# 3                      Un bon bock       0      1892     NaN             12
# 4                 Blacksmith Scene       0      1893     NaN              1
# ...                            ...     ...       ...     ...            ...
# 9806292              Episode #3.17       0      2010     NaN            NaN
# 9806293              Episode #3.19       0      2010     NaN            NaN
# 9806294              Episode #3.20       0      2010     NaN            NaN
# 9806295                   The Wind       0      2015     NaN             27
# 9806296  Horrid Henry Knows It All       0      2014     NaN             10
#
#                              genres
# 0                 Documentary,Short
# 1                   Animation,Short
# 2          Animation,Comedy,Romance
# 3                   Animation,Short
# 4                      Comedy,Short
# ...                             ...
# 9806292         Action,Drama,Family
# 9806293         Action,Drama,Family
# 9806294         Action,Drama,Family
# 9806295                       Short
# 9806296  Adventure,Animation,Comedy
#
# [9806297 rows x 9 columns]

# %% [markdown]
# ## Eliminate movies that are null for runtimeMinutes

# %%
#Checking null count
basics['runtimeMinutes'].isna().sum()
# Out:
# 6917265

# %%
#Resource for dropping null values - 
#https://stackoverflow.com/questions/49291740/delete-rows-if-there-are-null-values-in-a-specific-column-in-pandas-dataframe
basics = basics.dropna(axis=0, subset=['runtimeMinutes'])

# %%
#Checking null count to ensure values were removed
basics['runtimeMinutes'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Eliminate movies that are null for genre

# %%
#Same as above, getting null count then removing nulls and getting another count
#to ensure change.
basics['genres'].isna().sum()
# Out:
# 76575

# %%
basics = basics.dropna(axis=0, subset=['genres'])

# %%
basics['genres'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Keep only titleType==Movie

# %%
#Viewing value_counts() to ensure we only keep titleType movie
basics['titleType'].value_counts()
# Out:
# tvEpisode       1425631
# short            599275
# movie            381476
# video            180144
# tvMovie           91428
# tvSeries          90217
# tvSpecial         18051
# tvMiniSeries      17123
# tvShort            8790
# videoGame           322
# Name: titleType, dtype: int64

# %%
#Saving titleType movie to dataframe
basics = basics[basics['titleType']== 'movie']
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 144      tt0000147     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# ...            ...       ...
# 9806063  tt9916362     movie
# 9806147  tt9916538     movie
# 9806188  tt9916622     movie
# 9806215  tt9916680     movie
# 9806247  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 144                          The Corbett-Fitzsimmons Fight
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 9806063                                              Coven
# 9806147                                Kuambil Lagi Hatiku
# 9806188        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9806215  De la ilusión al desconcierto: cine colombiano...
# 9806247                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 144                          The Corbett-Fitzsimmons Fight       0      1897
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# ...                                                    ...     ...       ...
# 9806063                                           Akelarre       0      2020
# 9806147                                Kuambil Lagi Hatiku       0      2019
# 9806188        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9806215  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9806247                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 144         NaN            100      Documentary,News,Sport
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# ...         ...            ...                         ...
# 9806063     NaN             92               Drama,History
# 9806147     NaN            123                       Drama
# 9806188     NaN             57                 Documentary
# 9806215     NaN            100                 Documentary
# 9806247     NaN             49                 Documentary
#
# [381476 rows x 9 columns]

# %%
#Getting value counts to ensure movie is the only value in titleType column
basics['titleType'].value_counts()
# Out:
# movie    381476
# Name: titleType, dtype: int64

# %% [markdown]
# ## Keep startYear 2000-2022 (change to float)

# %%
basics['startYear'] = basics['startYear'].astype(float)

# %%
#Checking data type for conversion to float
basics['startYear'].dtype
# Out:
# dtype('float64')

# %%
#Resource- https://stackoverflow.com/questions/29370057/select-dataframe-rows-between-two-dates
basics = basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]
basics
# Out:
#             tconst titleType  \
# 13082    tt0013274     movie
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# ...            ...       ...
# 9806063  tt9916362     movie
# 9806147  tt9916538     movie
# 9806188  tt9916622     movie
# 9806215  tt9916680     movie
# 9806247  tt9916754     movie
#
#                                               primaryTitle  \
# 13082                          Istoriya grazhdanskoy voyny
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# ...                                                    ...
# 9806063                                              Coven
# 9806147                                Kuambil Lagi Hatiku
# 9806188        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9806215  De la ilusión al desconcierto: cine colombiano...
# 9806247                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult  startYear  \
# 13082                          Istoriya grazhdanskoy voyny       0     2021.0
# 34803                                       Kate & Leopold       0     2001.0
# 61116            El tango del viudo y su espejo deformante       0     2020.0
# 67669                           The Other Side of the Wind       0     2018.0
# 77964                                        November 1828       0     2001.0
# ...                                                    ...     ...        ...
# 9806063                                           Akelarre       0     2020.0
# 9806147                                Kuambil Lagi Hatiku       0     2019.0
# 9806188        Rodolpho Teóphilo - O Legado de um Pioneiro       0     2015.0
# 9806215  De la ilusión al desconcierto: cine colombiano...       0     2007.0
# 9806247                     Chico Albuquerque - Revelações       0     2013.0
#
#         endYear runtimeMinutes                  genres
# 13082       NaN             94             Documentary
# 34803       NaN            118  Comedy,Fantasy,Romance
# 61116       NaN             70                   Drama
# 67669       NaN            122                   Drama
# 77964       NaN            140               Drama,War
# ...         ...            ...                     ...
# 9806063     NaN             92           Drama,History
# 9806147     NaN            123                   Drama
# 9806188     NaN             57             Documentary
# 9806215     NaN            100             Documentary
# 9806247     NaN             49             Documentary
#
# [210349 rows x 9 columns]

# %% [markdown]
# ## Eliminate movies that include "Documentary" in genre (see tip below)

# %%
#Getting value count to ensure change
basics['genres'].value_counts()
# Out:
# Documentary                 49978
# Drama                       33767
# Comedy                      12603
# Comedy,Drama                 6125
# Horror                       5332
#                             ...
# Biography,Drama,News            1
# History,Mystery                 1
# Music,Reality-TV                1
# Biography,Family,Musical        1
# Action,Crime,Short              1
# Name: genres, Length: 1172, dtype: int64

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
#Getting value count to ensure change
basics['genres'].value_counts()
# Out:
# Drama                         33767
# Comedy                        12603
# Comedy,Drama                   6125
# Horror                         5332
# Drama,Romance                  4128
#                               ...
# Action,Crime,Music                1
# Animation,Music,Romance           1
# Action,Animation,Game-Show        1
# Family,Musical,Sport              1
# Action,Crime,Short                1
# Name: genres, Length: 954, dtype: int64

# %% [markdown]
# ## Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

# %%
#Using filtered datafram to filter another dataframe
keepers = basics['tconst'].isin(akas_us['titleId'])

# %%
# #Save current dataframe to file.
basics.to_csv("Data/title_basics_cleaned.csv.gz",compression='gzip',index=False)

# %%
#Displaying filtered dataframe
basics = basics[keepers]
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81627 entries, 34803 to 9806063
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81627 non-null  object
#  1   titleType       81627 non-null  object
#  2   primaryTitle    81627 non-null  object
#  3   originalTitle   81627 non-null  object
#  4   isAdult         81627 non-null  object
#  5   startYear       81627 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  81627 non-null  object
#  8   genres          81627 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.2+ MB

# %% [markdown]
# # Ratings table:
# - Replace "\N" with np.nan (if any)
# - Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

# %%
# #Loading ratings dt
# ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
# ratings = pd.read_csv(ratings_url, sep='\t',
#                       low_memory=False)
# ratings.info()

# %%
#Save current dataframe to file.
#ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1966
# 1  tt0000002            5.8       263
# 2  tt0000003            6.5      1808
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2607

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1305933 entries, 0 to 1305932
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1305933 non-null  object
#  1   averageRating  1305933 non-null  float64
#  2   numVotes       1305933 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 29.9+ MB

# %% [markdown]
# ## Replace "\N" with np.nan (if any)

# %%
ratings.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# ## Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)

# %%
#Using filtered dataframe to filter another dataframe 
keepers =ratings['tconst'].isin(akas_us['titleId'])

# %%
# #Save current dataframe to file.
ratings.to_csv("Data/title_ratings_cleaned.csv.gz",compression='gzip',index=False)

# %%
#Displaying results
ratings = ratings[keepers]
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 496709 entries, 0 to 1305908
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         496709 non-null  object
#  1   averageRating  496709 non-null  float64
#  2   numVotes       496709 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 15.2+ MB
